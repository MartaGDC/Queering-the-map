# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Country, gdp value

# %%
gdp = pd.read_csv("../data/charactCountry/gdp/global_bank_gdp.csv", skiprows=4)
gdp.sample(5)
# Out:
#       Country Name Country Code     Indicator Name  Indicator Code  \
# 226     Seychelles          SYC  GDP (current US$)  NY.GDP.MKTP.CD
# 205   Saudi Arabia          SAU  GDP (current US$)  NY.GDP.MKTP.CD
# 257       Viet Nam          VNM  GDP (current US$)  NY.GDP.MKTP.CD
# 138      Sri Lanka          LKA  GDP (current US$)  NY.GDP.MKTP.CD
# 87   Guinea-Bissau          GNB  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 226  1.201203e+07  1.159202e+07  1.264203e+07  1.392303e+07  1.539303e+07
# 205           NaN           NaN           NaN           NaN           NaN
# 257           NaN           NaN           NaN           NaN           NaN
# 138  1.409874e+09  1.444328e+09  1.434156e+09  1.240672e+09  1.309748e+09
# 87            NaN           NaN           NaN           NaN           NaN
#
#              1965  ...          2014          2015          2016  \
# ...

# %%
gdp.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
gdp.drop(columns=['Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
                              '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
                              '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
                              '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
                              '2004', '2005', '2006', '2007', '2008', '2009', '2010', "2011", "2012", "2013", "2014", "2015",
                              "2016", 'Unnamed: 67'], inplace = True)

# %%
gdp.isna().sum() # To calculate the mean gdp since 2017, not every country has data about every year
# Out:
# Country Name     0
# Country Code     0
# 2017             8
# 2018             8
# 2019             9
# 2020             9
# 2021            15
# 2022            33
# dtype: int64

# %%
mean_gdp = []
for index, rows in gdp.iterrows():
    mean_gdp.append(np.nanmean([rows["2017"], rows["2018"], rows["2019"], rows["2020"], rows["2021"], rows["2022"]]))
gdp["mean_gdp"] = mean_gdp
# Out:
# C:\Users\gdcma\AppData\Local\Temp\ipykernel_28724\398264644.py:3: RuntimeWarning: Mean of empty slice
#   mean_gdp.append(np.nanmean([rows["2017"], rows["2018"], rows["2019"], rows["2020"], rows["2021"], rows["2022"]]))

# %%
gdp.isna().sum() # To calculate the mean gdp since 2017, not every country has data about every year
# Out:
# Country Name     0
# Country Code     0
# 2017             8
# 2018             8
# 2019             9
# 2020             9
# 2021            15
# 2022            33
# mean_gdp         8
# dtype: int64

# %%
gdp.sample()
# Out:
#    Country Name Country Code          2017          2018          2019  \
# 83        Ghana          GHA  6.040592e+10  6.729891e+10  6.833797e+10
#
#             2020          2021          2022      mean_gdp
# 83  7.004310e+10  7.915641e+10  7.283880e+10  6.968019e+10

# %%
gdp.loc[gdp[gdp["mean_gdp"].isna()].index]
# Out:
#                   Country Name Country Code  2017  2018  2019  2020  2021  \
# 69                     Eritrea          ERI   NaN   NaN   NaN   NaN   NaN
# 84                   Gibraltar          GIB   NaN   NaN   NaN   NaN   NaN
# 110             Not classified          INX   NaN   NaN   NaN   NaN   NaN
# 147   St. Martin (French part)          MAF   NaN   NaN   NaN   NaN   NaN
# 193  Korea, Dem. People's Rep.          PRK   NaN   NaN   NaN   NaN   NaN
# 216                South Sudan          SSD   NaN   NaN   NaN   NaN   NaN
# 254              Venezuela, RB          VEN   NaN   NaN   NaN   NaN   NaN
# 255     British Virgin Islands          VGB   NaN   NaN   NaN   NaN   NaN
#
#      2022  mean_gdp
# 69    NaN       NaN
# 84    NaN       NaN
# 110   NaN       NaN
# 147   NaN       NaN
# 193   NaN       NaN
# 216   NaN       NaN
# 254   NaN       NaN
# 255   NaN       NaN

# %%
gdp.to_csv("../data/charactCountry/gdp/gdp.csv")
